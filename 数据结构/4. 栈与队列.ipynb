# %% [markdown]
# ### 顺序表、链表等线性表定义好如何存储数据后，可通过限制其操作实现栈、队列。
#
# ### 顺序表、链表关注数据的存储。
#
# ### 栈和队列关注其特殊的机制，在具体场景的应用。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 栈的实现

# %% [markdown]
# #### 栈的操作
#
# - Stack() 创建一个新的空栈
#
# - push(item) 入栈
#
# - pop() 出栈
#
# - peek() 返回栈顶元素
#
# - is_empty() 判断栈是否为空
#
# - size() 返回栈的元素个数

# %%
 class Stack(object):
        """栈"""
        def __init__(self):
            self.__list = [] #根据选择容器不同，选择栈顶在哪里不同，顺序表栈顶在尾部，链表栈顶在头部
            
        def push(self, item):
            """入栈"""
            self.__list.append(item)
            
        def pop(self):
            """出栈"""
            return self.__list.pop()
            
        def peek(self):
            """返回栈顶元素"""
            if self.__list:
                return self.__list[-1]
            else:
                return None
                
        def is_empty(self):
            """判断栈是否为空"""
            return self.__list == []
            # return not self.__list
            # 0 "" {} () [] 在逻辑值上是假的
        
        def size(self):
            """返回栈的元素个数"""
            return len(self.__list)

# %%
s = Stack()
s.push(1)
s.push(2)
s.push(3)

# %%
s.pop()
# Out:
# 3

# %%
s.pop()
# Out:
# 2

# %%
s.pop()
# Out:
# 1

# %% [markdown]
# ## 队列的实现
#
# #### 队列的操作
#
# - Queue() 创建一个新的空队列
#
# - enqueue(item) 向队列中添加一个item元素
#
# - dequeue() 从队列头部删除一个元素
#
# - is_empty() 判断一个队列是否为空
#
# - size() 返回队列的大小

# %%
 class Queue(object):
        """队列"""
        def __init__(self):
            self.__list = [] 
            
        def enqueue(self, item):
            """入队"""
            self.__list.append(item)
            
        def dequeue(self):  # 如果出队操作更多，使用链表更好，入队操作更多，使用顺序表更好
            return self.__list.pop(0)
                
        def is_empty(self):
            """判断队列是否为空"""
            return self.__list == []
            # return not self.__list
            # 0 "" {} () [] 在逻辑值上是假的
        
        def size(self):
            """返回队列的元素个数"""
            return len(self.__list)

# %%
q = Queue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)

# %%
q.dequeue()
# Out:
# 1

# %%
q.dequeue()
# Out:
# 2

# %% [markdown]
# ## 双端队列
#
# ![image.png](attachment:image.png)
#
# #### 双端队列的操作
#
# - Deque() 创建一个空的双端队列
#
#
# - add_front(item)  从队头加入一个item元素
#
#
# - add_rear(item)  从队尾加入一个item元素
#
#
# - remove_front()  从队头删除一个元素
#
#
# - remove_rear()  从队尾删除一个元素
#
#
# - is_empty()  判断双端队列是否为空
#
#
# - size() 返回队列大小

# %%
  class Deque(object):
        """双端队列"""
        def __init__(self):
            self.__list = [] 
            
        def add_front(self, item):
            """从队头加入一个item元素"""
            self.__list.insert(0,item)
            
        def add_rear(self, item):
            """从队尾加入一个item元素"""
            self.__list.append(item)
            
        def remove_front(self):
            """从队头删除一个元素"""
            return self.__list.pop(0)
        
        def remove_rear(self):
            """ 从队尾删除一个元素"""
            return self.__list.pop()
                
        def is_empty(self):
            """判断队列是否为空"""
            return self.__list == []
            # return not self.__list
            # 0 "" {} () [] 在逻辑值上是假的
        
        def size(self):
            """返回队列的元素个数"""
            return len(self.__list)

# %%
dq = Deque()
dq.add_front(1)

# %%
dq.add_front(2)
dq.add_rear(3)
dq.add_rear(5)

# %%
dq.remove_front()
# Out:
# 2

# %%
dq.remove_rear()
# Out:
# 5
