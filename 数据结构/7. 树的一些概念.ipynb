# %% [markdown]
# ## 总结
#
# #### 什么是树？
#
# #### 树的种类：二叉树（完全二叉树、满二叉树、平衡二叉树、排序二叉树）
#
# #### 树的存储：链表
#
# #### 树的应用：html、数据库索引、机器学习算法...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 完全二叉树
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 满二叉树
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### \*排序二叉树
#
# **跟选择排序算法思想相似**
#
# （1）若左子树不空，则左子树上所有结点的值均小于它的根结点的值；
#
# （2）若右子树不空，则右子树上所有结点的值均大于它的根结点的值；
#
# （3）左、右子树也分别为二叉排序树；
#
# （4）没有键值相等的结点。
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
