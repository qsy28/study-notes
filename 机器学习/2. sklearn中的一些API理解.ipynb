# %% [markdown]
# ### 数据集的获取：sklearn中有的数据集

# %% [markdown]
# **`sklearn.datasets`**
#
# 加载获取流行数据集
#
# \-----------------------------------
#
# datasets.load_*()
#
# 获取小规模数据集，数据包含在datasets里
#
# \-----------------------------------
#
# datasets.fetch_*(data_home=None)
#
# 获取大规模数据集，需要从网络上下载，函数的第一个参数是data_home，表示数据集下载的目录,默认是 ~/scikit_learn_data/\

# %% [markdown]
# load*和fetch*返回的数据类型datasets.base.Bunch(字典格式)
#
# - data：特征数据数组，是 [n_samples * n_features] 的二维numpy.ndarray 数组
#
# - target：标签数组，是 n_samples 的一维 numpy.ndarray 数组
#
# - DESCR：数据描述
#
# - feature_names：特征名,新闻数据，手写数字、回归数据集没有
#
# - target_names：标签名,回归数据集没有

# %%
from sklearn.datasets import load_iris #鸢尾花数据集(分类数据集)
iris = load_iris()
iris.data[:5,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
iris.feature_names #对应列
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
from sklearn.datasets import load_boston #波士顿房价（回归数据集）

bs = load_boston()
bs.data.shape
# Out:
# (506, 13)

# %%
bs.target[:5]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %% [markdown]
# ### 数据集的划分：训练集与测试集

# %% [markdown]
# `sklearn.model_selection.train_test_split(*arrays, **options)`
#
# x: 数据集的特征值
#
# y: 数据集的标签值
#
# test_size: 测试集的大小，一般为float
#
# random_state: 随机数种子,不同的种子会造成不同的随机采样结果。相同的种子采样结果相同。
#
# **return  训练集特征值，测试集特征值，训练标签，测试标签** (这个顺序是固定的！)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size = 0.25)
print("训练集：")
print(x_train.shape)
print(x_train[:5])
print(y_train[:5])
print("测试集：")
print(x_test.shape)
print(x_test[:5])
print(y_test[:5])
# Out:
# 训练集：
# (112, 4)
# [[4.4 3.2 1.3 0.2]
#  [5.9 3.2 4.8 1.8]
#  [6.3 2.5 4.9 1.5]
#  [5.8 2.7 3.9 1.2]
#  [5.4 3.4 1.5 0.4]]
# [0 1 1 1 0]
# 测试集：
# (38, 4)
# [[5.  3.5 1.6 0.6]
#  [5.7 2.9 4.2 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.5 3.5 1.3 0.2]
#  [5.1 3.3 1.7 0.5]]
# [0 1 2 0 0]

# %% [markdown]
# ### 转换器与估计器
#
# **转换器：**特征工程中实例化过程，实例的是一个转换器类Transformer!
#
# sklearn.feature_extraction.DictVectorizer
#
# sklearn.feature_extraction.text.CountVectorizer
#
# sklearn.feature_extraction.text.TfidfVectorizer
#
# ....
#
# > fit_transform() = fit() + transform()     【transform() 是在fit计算的基础上进行转化的】
#
#
#
# **估计器：**在sklearn中，估计器(estimator)是一个重要的角色，分类器和回归器都属于estimator，是一类实现了算法的API
#
# 1、用于分类的估计器：
#
# sklearn.neighbors	k-近邻算法
#
# sklearn.naive_bayes      贝叶斯
#
# sklearn.linear_model.LogisticRegression     逻辑回归
#
#
# \----------
#
#
# 2、用于回归的估计器：
#
# sklearn.linear_model.LinearRegression     线性回归
#
# sklearn.linear_model.Ridge      岭回归
#
# **估计器的工作流程**
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### 具体用法可以通过学习后面各种算法后记忆
